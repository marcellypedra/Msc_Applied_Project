# %% [markdown]
# Decoding adult23.xlsx within codebook dictionary

# %%
import pandas as pd 
import codebook_dictionary
# Out:
# Traceback (most recent call last):
#
#   File /Msc_Applied_Project/MscProject/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     import codebook_dictionary
#
#   File /Msc_Applied_Project/codebook_dictionary.py:163
#     01:"Hispanic  ",
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import pandas as pd 
import codebook_dictionary

df = pd.read_excel ("adult23_cleaned.xlsx", engine="openpyxl")

if "AGE65" in df.columns:
    df["AGE65"] = df["AGE65"].map(codebook_dict.AGE65)

if "AGEP_A" in df.columns:
    df["AGEP_A"] = df["AGEP_A"].map(codebook_dict.AGEP_A)
    
if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dict.SEX_A)

if "AHEARST1_A" in df.columns:
    df["AHEARST1_A"] = df["AHEARST1_A"].map(codebook_dict.AHEARST1_A)

if "ANXEV_A" in df.columns:
    df["ANXEV_A"] = df["ANXEV_A"].map(codebook_dict.ANXEV_A)

if "ANXFREQ_A" in df.columns:
    df["ANXFREQ_A"] = df["ANXFREQ_A"].map(codebook_dict.ANXFREQ_A)

if "ANXLEVEL_A" in df.columns:
    df["ANXLEVEL_A"] = df["ANXLEVEL_A"].map(codebook_dict.ANXLEVEL_A)

if "ANXMED_A" in df.columns:
    df["ANXMED_A"] = df["ANXMED_A"].map(codebook_dict.ANXMED_A)

if "CANEWLKR_A" in df.columns:
    df["CANEWLKR_A"] = df["CANEWLKR_A"].map(codebook_dict.CANEWLKR_A)

if "CITZNSTP_A" in df.columns:
    df["CITZNSTP_A"] = df["CITZNSTP_A"].map(codebook_dict.CITZNSTP_A)

if "DEMENEV_A" in df.columns:
    df["DEMENEV_A"] = df["DEMENEV_A"].map(codebook_dict.DEMENEV_A)

if "DEPEV_A" in df.columns:
    df["DEPEV_A"] = df["DEPEV_A"].map(codebook_dict.DEPEV_A)

if "DEPFREQ_A" in df.columns:
    df["DEPFREQ_A"] = df["DEPFREQ_A"].map(codebook_dict.DEPFREQ_A)

if "DEPLEVEL_A" in df.columns:
    df["DEPLEVEL_A"] = df["DEPLEVEL_A"].map(codebook_dict.DEPLEVEL_A)

if "DEPMED_A" in df.columns:
    df["DEPMED_A"] = df["DEPMED_A"].map(codebook_dict.DEPMED_A)

if "DISAB3_A" in df.columns:
    df["DISAB3_A"] = df["DISAB3_A"].map(codebook_dict.DISAB3_A)

if "EQUIP_A" in df.columns:
    df["EQUIP_A"] = df["EQUIP_A"].map(codebook_dict.EQUIP_A)

if "GAD2SCREEN_A" in df.columns:
    df["GAD2SCREEN_A"] = df["GAD2SCREEN_A"].map(codebook_dict.GAD2SCREEN_A)

if "HEARAID_A" in df.columns:
    df["HEARAID_A"] = df["HEARAID_A"].map(codebook_dict.HEARAID_A)

if "HISDETP_A" in df.columns:
    df["HISDETP_A"] = df["HISDETP_A"].map(codebook_dict.HISDETP_A)

if "HISPALLP_A" in df.columns:
    df["HISPALLP_A"] = df["HISPALLP_A"].map(codebook_dict.HISPALLP_A)

if "HISP_A" in df.columns:
    df["HISP_A"] = df["HISP_A"].map(codebook_dict.HISP_A)

if "IHS_A" in df.columns:
    df["IHS_A"] = df["IHS_A"].map(codebook_dict.IHS_A)

if "LANGDOC_A" in df.columns:
    df["LANGDOC_A"] = df["LANGDOC_A"].map(codebook_dict.LANGDOC_A)

if "LANGHM_A" in df.columns:
    df["LANGHM_A"] = df["LANGHM_A"].map(codebook_dict.LANGHM_A)

if "LANGMED_A" in df.columns:
    df["LANGMED_A"] = df["LANGMED_A"].map(codebook_dict.LANGMED_A)

if "LANGSOC_A" in df.columns:
    df["LANGSOC_A"] = df["LANGSOC_A"].map(codebook_dict.LANGSOC_A)

if "LANGSPECR_A" in df.columns:
    df["LANGSPECR_A"] = df["LANGSPECR_A"].map(codebook_dict.LANGSPECR_A)

if "LSATIS4_A" in df.columns:
    df["LSATIS4_A"] = df["LSATIS4_A"].map(codebook_dict.LSATIS4_A)

if "MHRX_A" in df.columns:
    df["MHRX_A"] = df["MHRX_A"].map(codebook_dict.MHRX_A)

if "MHTHND_A" in df.columns:
    df["MHTHND_A"] = df["MHTHND_A"].map(codebook_dict.MHTHND_A)

if "MHTHRPY_A" in df.columns:
    df["MHTHRPY_A"] = df["MHTHRPY_A"].map(codebook_dict.MHTHRPY_A)

if "MHTPYNOW_A" in df.columns:
    df["MHTPYNOW_A"] = df["MHTPYNOW_A"].map(codebook_dict.MHTPYNOW_A)

if "PHQ2SCREEN_A" in df.columns:
    df["PHQ2SCREEN_A"] = df["PHQ2SCREEN_A"].map(codebook_dict.PHQ2SCREEN_A)

if "PHQ41_A" in df.columns:
    df["PHQ41_A"] = df["PHQ41_A"].map(codebook_dict.PHQ41_A)

if "PHQ42_A" in df.columns:
    df["PHQ42_A"] = df["PHQ42_A"].map(codebook_dict.PHQ42_A)

if "PHQ43_A" in df.columns:
    df["PHQ43_A"] = df["PHQ43_A"].map(codebook_dict.PHQ43_A)

if "PHQ44_A" in df.columns:
    df["PHQ44_A"] = df["PHQ44_A"].map(codebook_dict.PHQ44_A)

if "PHSTAT_A" in df.columns:
    df["PHSTAT_A"] = df["PHSTAT_A"].map(codebook_dict.PHSTAT_A)

if "PRTNRAGETC_A" in df.columns:
    df["PRTNRAGETC_A"] = df["PRTNRAGETC_A"].map(codebook_dict.PRTNRAGETC_A)

if "PRTNRSEX_A" in df.columns:
    df["PRTNRSEX_A"] = df["PRTNRSEX_A"].map(codebook_dict.PRTNRSEX_A)

if "RACEALLP_A" in df.columns:
    df["RACEALLP_A"] = df["RACEALLP_A"].map(codebook_dict.RACEALLP_A)

if "SASPPHISP_A" in df.columns:
    df["SASPPHISP_A"] = df["SASPPHISP_A"].map(codebook_dict.SASPPHISP_A)

if "SASPPRACE_A" in df.columns:
    df["SASPPRACE_A"] = df["SASPPRACE_A"].map(codebook_dict.SASPPRACE_A)

if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dict.SEX_A)

if "SPOUSAGETC_A" in df.columns:
    df["SPOUSAGETC_A"] = df["SPOUSAGETC_A"].map(codebook_dict.SPOUSAGETC_A)

if "SPOUSESEX_A" in df.columns:
    df["SPOUSESEX_A"] = df["SPOUSESEX_A"].map(codebook_dict.SPOUSESEX_A)

if "WCHAIR_A" in df.columns:
    df["WCHAIR_A"] = df["WCHAIR_A"].map(codebook_dict.WCHAIR_A)

if "YRSINUS_A" in df.columns:
    df["YRSINUS_A"] = df["YRSINUS_A"].map(codebook_dict.YRSINUS_A)

df.to_excel("adult23_decoded.xlsx", index=False, engine="openpyxl")

print("Decoded excel file saved as 'adult23_decoded.xlsx'")
# Out:
# Traceback (most recent call last):
#
#   File /Msc_Applied_Project/MscProject/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 2
#     import codebook_dictionary
#
#   File /Msc_Applied_Project/codebook_dictionary.py:163
#     01:"Hispanic  ",
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import pandas as pd 
import codebook_dictionary

# %%
df = pd.read_excel ("adult23_cleaned.xlsx", engine="openpyxl")

if "AGE65" in df.columns:
    df["AGE65"] = df["AGE65"].map(codebook_dict.AGE65)

if "AGEP_A" in df.columns:
    df["AGEP_A"] = df["AGEP_A"].map(codebook_dict.AGEP_A)
    
if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dict.SEX_A)

if "AHEARST1_A" in df.columns:
    df["AHEARST1_A"] = df["AHEARST1_A"].map(codebook_dict.AHEARST1_A)

if "ANXEV_A" in df.columns:
    df["ANXEV_A"] = df["ANXEV_A"].map(codebook_dict.ANXEV_A)

if "ANXFREQ_A" in df.columns:
    df["ANXFREQ_A"] = df["ANXFREQ_A"].map(codebook_dict.ANXFREQ_A)

if "ANXLEVEL_A" in df.columns:
    df["ANXLEVEL_A"] = df["ANXLEVEL_A"].map(codebook_dict.ANXLEVEL_A)

if "ANXMED_A" in df.columns:
    df["ANXMED_A"] = df["ANXMED_A"].map(codebook_dict.ANXMED_A)

if "CANEWLKR_A" in df.columns:
    df["CANEWLKR_A"] = df["CANEWLKR_A"].map(codebook_dict.CANEWLKR_A)

if "CITZNSTP_A" in df.columns:
    df["CITZNSTP_A"] = df["CITZNSTP_A"].map(codebook_dict.CITZNSTP_A)

if "DEMENEV_A" in df.columns:
    df["DEMENEV_A"] = df["DEMENEV_A"].map(codebook_dict.DEMENEV_A)

if "DEPEV_A" in df.columns:
    df["DEPEV_A"] = df["DEPEV_A"].map(codebook_dict.DEPEV_A)

if "DEPFREQ_A" in df.columns:
    df["DEPFREQ_A"] = df["DEPFREQ_A"].map(codebook_dict.DEPFREQ_A)

if "DEPLEVEL_A" in df.columns:
    df["DEPLEVEL_A"] = df["DEPLEVEL_A"].map(codebook_dict.DEPLEVEL_A)

if "DEPMED_A" in df.columns:
    df["DEPMED_A"] = df["DEPMED_A"].map(codebook_dict.DEPMED_A)

if "DISAB3_A" in df.columns:
    df["DISAB3_A"] = df["DISAB3_A"].map(codebook_dict.DISAB3_A)

if "EQUIP_A" in df.columns:
    df["EQUIP_A"] = df["EQUIP_A"].map(codebook_dict.EQUIP_A)

if "GAD2SCREEN_A" in df.columns:
    df["GAD2SCREEN_A"] = df["GAD2SCREEN_A"].map(codebook_dict.GAD2SCREEN_A)

if "HEARAID_A" in df.columns:
    df["HEARAID_A"] = df["HEARAID_A"].map(codebook_dict.HEARAID_A)

if "HISDETP_A" in df.columns:
    df["HISDETP_A"] = df["HISDETP_A"].map(codebook_dict.HISDETP_A)

if "HISPALLP_A" in df.columns:
    df["HISPALLP_A"] = df["HISPALLP_A"].map(codebook_dict.HISPALLP_A)

if "HISP_A" in df.columns:
    df["HISP_A"] = df["HISP_A"].map(codebook_dict.HISP_A)

if "IHS_A" in df.columns:
    df["IHS_A"] = df["IHS_A"].map(codebook_dict.IHS_A)

if "LANGDOC_A" in df.columns:
    df["LANGDOC_A"] = df["LANGDOC_A"].map(codebook_dict.LANGDOC_A)

if "LANGHM_A" in df.columns:
    df["LANGHM_A"] = df["LANGHM_A"].map(codebook_dict.LANGHM_A)

if "LANGMED_A" in df.columns:
    df["LANGMED_A"] = df["LANGMED_A"].map(codebook_dict.LANGMED_A)

if "LANGSOC_A" in df.columns:
    df["LANGSOC_A"] = df["LANGSOC_A"].map(codebook_dict.LANGSOC_A)

if "LANGSPECR_A" in df.columns:
    df["LANGSPECR_A"] = df["LANGSPECR_A"].map(codebook_dict.LANGSPECR_A)

if "LSATIS4_A" in df.columns:
    df["LSATIS4_A"] = df["LSATIS4_A"].map(codebook_dict.LSATIS4_A)

if "MHRX_A" in df.columns:
    df["MHRX_A"] = df["MHRX_A"].map(codebook_dict.MHRX_A)

if "MHTHND_A" in df.columns:
    df["MHTHND_A"] = df["MHTHND_A"].map(codebook_dict.MHTHND_A)

if "MHTHRPY_A" in df.columns:
    df["MHTHRPY_A"] = df["MHTHRPY_A"].map(codebook_dict.MHTHRPY_A)

if "MHTPYNOW_A" in df.columns:
    df["MHTPYNOW_A"] = df["MHTPYNOW_A"].map(codebook_dict.MHTPYNOW_A)

if "PHQ2SCREEN_A" in df.columns:
    df["PHQ2SCREEN_A"] = df["PHQ2SCREEN_A"].map(codebook_dict.PHQ2SCREEN_A)

if "PHQ41_A" in df.columns:
    df["PHQ41_A"] = df["PHQ41_A"].map(codebook_dict.PHQ41_A)

if "PHQ42_A" in df.columns:
    df["PHQ42_A"] = df["PHQ42_A"].map(codebook_dict.PHQ42_A)

if "PHQ43_A" in df.columns:
    df["PHQ43_A"] = df["PHQ43_A"].map(codebook_dict.PHQ43_A)

if "PHQ44_A" in df.columns:
    df["PHQ44_A"] = df["PHQ44_A"].map(codebook_dict.PHQ44_A)

if "PHSTAT_A" in df.columns:
    df["PHSTAT_A"] = df["PHSTAT_A"].map(codebook_dict.PHSTAT_A)

if "PRTNRAGETC_A" in df.columns:
    df["PRTNRAGETC_A"] = df["PRTNRAGETC_A"].map(codebook_dict.PRTNRAGETC_A)

if "PRTNRSEX_A" in df.columns:
    df["PRTNRSEX_A"] = df["PRTNRSEX_A"].map(codebook_dict.PRTNRSEX_A)

if "RACEALLP_A" in df.columns:
    df["RACEALLP_A"] = df["RACEALLP_A"].map(codebook_dict.RACEALLP_A)

if "SASPPHISP_A" in df.columns:
    df["SASPPHISP_A"] = df["SASPPHISP_A"].map(codebook_dict.SASPPHISP_A)

if "SASPPRACE_A" in df.columns:
    df["SASPPRACE_A"] = df["SASPPRACE_A"].map(codebook_dict.SASPPRACE_A)

if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dict.SEX_A)

if "SPOUSAGETC_A" in df.columns:
    df["SPOUSAGETC_A"] = df["SPOUSAGETC_A"].map(codebook_dict.SPOUSAGETC_A)

if "SPOUSESEX_A" in df.columns:
    df["SPOUSESEX_A"] = df["SPOUSESEX_A"].map(codebook_dict.SPOUSESEX_A)

if "WCHAIR_A" in df.columns:
    df["WCHAIR_A"] = df["WCHAIR_A"].map(codebook_dict.WCHAIR_A)

if "YRSINUS_A" in df.columns:
    df["YRSINUS_A"] = df["YRSINUS_A"].map(codebook_dict.YRSINUS_A)

df.to_excel("adult23_decoded.xlsx", index=False, engine="openpyxl")

print("Decoded excel file saved as 'adult23_decoded.xlsx'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 df = pd.read_excel ("adult23_cleaned.xlsx", engine="openpyxl")
#       3 if "AGE65" in df.columns:
# ----> 4     df["AGE65"] = df["AGE65"].map(codebook_dict.AGE65)
#       6 if "AGEP_A" in df.columns:
#       7     df["AGEP_A"] = df["AGEP_A"].map(codebook_dict.AGEP_A)
#
# NameError: name 'codebook_dict' is not defined

# %%
df = pd.read_excel ("adult23_cleaned.xlsx", engine="openpyxl")

if "AGE65" in df.columns:
    df["AGE65"] = df["AGE65"].map(codebook_dictionary.AGE65)

if "AGEP_A" in df.columns:
    df["AGEP_A"] = df["AGEP_A"].map(codebook_dictionary.AGEP_A)
    
if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dictionary.SEX_A)

if "AHEARST1_A" in df.columns:
    df["AHEARST1_A"] = df["AHEARST1_A"].map(codebook_dictionary.AHEARST1_A)

if "ANXEV_A" in df.columns:
    df["ANXEV_A"] = df["ANXEV_A"].map(codebook_dictionary.ANXEV_A)

if "ANXFREQ_A" in df.columns:
    df["ANXFREQ_A"] = df["ANXFREQ_A"].map(codebook_dictionary.ANXFREQ_A)

if "ANXLEVEL_A" in df.columns:
    df["ANXLEVEL_A"] = df["ANXLEVEL_A"].map(codebook_dictionary.ANXLEVEL_A)

if "ANXMED_A" in df.columns:
    df["ANXMED_A"] = df["ANXMED_A"].map(codebook_dictionary.ANXMED_A)

if "CANEWLKR_A" in df.columns:
    df["CANEWLKR_A"] = df["CANEWLKR_A"].map(codebook_dictionary.CANEWLKR_A)

if "CITZNSTP_A" in df.columns:
    df["CITZNSTP_A"] = df["CITZNSTP_A"].map(codebook_dictionary.CITZNSTP_A)

if "DEMENEV_A" in df.columns:
    df["DEMENEV_A"] = df["DEMENEV_A"].map(codebook_dictionary.DEMENEV_A)

if "DEPEV_A" in df.columns:
    df["DEPEV_A"] = df["DEPEV_A"].map(codebook_dictionary.DEPEV_A)

if "DEPFREQ_A" in df.columns:
    df["DEPFREQ_A"] = df["DEPFREQ_A"].map(codebook_dictionary.DEPFREQ_A)

if "DEPLEVEL_A" in df.columns:
    df["DEPLEVEL_A"] = df["DEPLEVEL_A"].map(codebook_dictionary.DEPLEVEL_A)

if "DEPMED_A" in df.columns:
    df["DEPMED_A"] = df["DEPMED_A"].map(codebook_dictionary.DEPMED_A)

if "DISAB3_A" in df.columns:
    df["DISAB3_A"] = df["DISAB3_A"].map(codebook_dictionary.DISAB3_A)

if "EQUIP_A" in df.columns:
    df["EQUIP_A"] = df["EQUIP_A"].map(codebook_dictionary.EQUIP_A)

if "GAD2SCREEN_A" in df.columns:
    df["GAD2SCREEN_A"] = df["GAD2SCREEN_A"].map(codebook_dictionary.GAD2SCREEN_A)

if "HEARAID_A" in df.columns:
    df["HEARAID_A"] = df["HEARAID_A"].map(codebook_dictionary.HEARAID_A)

if "HISDETP_A" in df.columns:
    df["HISDETP_A"] = df["HISDETP_A"].map(codebook_dictionary.HISDETP_A)

if "HISPALLP_A" in df.columns:
    df["HISPALLP_A"] = df["HISPALLP_A"].map(codebook_dictionary.HISPALLP_A)

if "HISP_A" in df.columns:
    df["HISP_A"] = df["HISP_A"].map(codebook_dictionary.HISP_A)

if "IHS_A" in df.columns:
    df["IHS_A"] = df["IHS_A"].map(codebook_dictionary.IHS_A)

if "LANGDOC_A" in df.columns:
    df["LANGDOC_A"] = df["LANGDOC_A"].map(codebook_dictionary.LANGDOC_A)

if "LANGHM_A" in df.columns:
    df["LANGHM_A"] = df["LANGHM_A"].map(codebook_dictionary.LANGHM_A)

if "LANGMED_A" in df.columns:
    df["LANGMED_A"] = df["LANGMED_A"].map(codebook_dictionary.LANGMED_A)

if "LANGSOC_A" in df.columns:
    df["LANGSOC_A"] = df["LANGSOC_A"].map(codebook_dictionary.LANGSOC_A)

if "LANGSPECR_A" in df.columns:
    df["LANGSPECR_A"] = df["LANGSPECR_A"].map(codebook_dictionary.LANGSPECR_A)

if "LSATIS4_A" in df.columns:
    df["LSATIS4_A"] = df["LSATIS4_A"].map(codebook_dictionary.LSATIS4_A)

if "MHRX_A" in df.columns:
    df["MHRX_A"] = df["MHRX_A"].map(codebook_dictionary.MHRX_A)

if "MHTHND_A" in df.columns:
    df["MHTHND_A"] = df["MHTHND_A"].map(codebook_dictionary.MHTHND_A)

if "MHTHRPY_A" in df.columns:
    df["MHTHRPY_A"] = df["MHTHRPY_A"].map(codebook_dictionary.MHTHRPY_A)

if "MHTPYNOW_A" in df.columns:
    df["MHTPYNOW_A"] = df["MHTPYNOW_A"].map(codebook_dictionary.MHTPYNOW_A)

if "PHQ2SCREEN_A" in df.columns:
    df["PHQ2SCREEN_A"] = df["PHQ2SCREEN_A"].map(codebook_dictionary.PHQ2SCREEN_A)

if "PHQ41_A" in df.columns:
    df["PHQ41_A"] = df["PHQ41_A"].map(codebook_dictionary.PHQ41_A)

if "PHQ42_A" in df.columns:
    df["PHQ42_A"] = df["PHQ42_A"].map(codebook_dictionary.PHQ42_A)

if "PHQ43_A" in df.columns:
    df["PHQ43_A"] = df["PHQ43_A"].map(codebook_dictionary.PHQ43_A)

if "PHQ44_A" in df.columns:
    df["PHQ44_A"] = df["PHQ44_A"].map(codebook_dictionary.PHQ44_A)

if "PHSTAT_A" in df.columns:
    df["PHSTAT_A"] = df["PHSTAT_A"].map(codebook_dictionary.PHSTAT_A)

if "PRTNRAGETC_A" in df.columns:
    df["PRTNRAGETC_A"] = df["PRTNRAGETC_A"].map(codebook_dictionary.PRTNRAGETC_A)

if "PRTNRSEX_A" in df.columns:
    df["PRTNRSEX_A"] = df["PRTNRSEX_A"].map(codebook_dictionary.PRTNRSEX_A)

if "RACEALLP_A" in df.columns:
    df["RACEALLP_A"] = df["RACEALLP_A"].map(codebook_dictionary.RACEALLP_A)

if "SASPPHISP_A" in df.columns:
    df["SASPPHISP_A"] = df["SASPPHISP_A"].map(codebook_dictionary.SASPPHISP_A)

if "SASPPRACE_A" in df.columns:
    df["SASPPRACE_A"] = df["SASPPRACE_A"].map(codebook_dictionary.SASPPRACE_A)

if "SEX_A" in df.columns:
    df["SEX_A"] = df["SEX_A"].map(codebook_dictionary.SEX_A)

if "SPOUSAGETC_A" in df.columns:
    df["SPOUSAGETC_A"] = df["SPOUSAGETC_A"].map(codebook_dictionary.SPOUSAGETC_A)

if "SPOUSESEX_A" in df.columns:
    df["SPOUSESEX_A"] = df["SPOUSESEX_A"].map(codebook_dictionary.SPOUSESEX_A)

if "WCHAIR_A" in df.columns:
    df["WCHAIR_A"] = df["WCHAIR_A"].map(codebook_dictionary.WCHAIR_A)

if "YRSINUS_A" in df.columns:
    df["YRSINUS_A"] = df["YRSINUS_A"].map(codebook_dictionary.YRSINUS_A)

df.to_excel("adult23_decoded.xlsx", index=False, engine="openpyxl")

print("Decoded excel file saved as 'adult23_decoded.xlsx'")
# Out:
# Decoded excel file saved as 'adult23_decoded.xlsx'

# %%
file_path = 'adult23_decoded.xlsx'
try:
    df = pd.read_excel(file_path)
    print(df.head())
# Out:
#   Cell In[7], line 5
#
#     ^
# SyntaxError: incomplete input

# %%
import pandas as pd

# %%
file_path = 'adult23_decoded.xlsx'
try:
    df = pd.read_excel(file_path)
    print(df.head())
# Out:
#   Cell In[9], line 4
#     print(df.head())
#                     ^
# SyntaxError: incomplete input

# %%
file_path = 'adult23_decoded.xlsx'
try:
    df = pd.read_excel(file_path)
print("First 5 rows of the DataFrame:")
    print(df.head())
# Out:
#   Cell In[10], line 4
#     print("First 5 rows of the DataFrame:")
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
file_path = 'adult23_decoded.xlsx'
try:
    df = pd.read_excel(file_path)
print("First 5 rows of the DataFrame:")
    print(df.head())
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   Cell In[11], line 4
#     print("First 5 rows of the DataFrame:")
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
file_path = 'adult23_decoded.xlsx'
try:
    df = pd.read_excel(file_path)
    
    print("First 5 rows of the DataFrame:")
    print(df.head())

    print("\nDataFrame Info:")
    df.info()

except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please check the path.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# First 5 rows of the DataFrame:
#   LANGSPECR_A LANGSOC_A LANGDOC_A LANGMED_A LANGHM_A  \
# 0         NaN       NaN       NaN       NaN      NaN
# 1         NaN       NaN       NaN       NaN      NaN
# 2         NaN       NaN       NaN       NaN      NaN
# 3         NaN       NaN       NaN       NaN      NaN
# 4         NaN       NaN       NaN       NaN      NaN
#
#                                   HISPALLP_A                    RACEALLP_A  \
# 0  Non-Hispanic Black/African American only   Black/African American only
# 1                  Non-Hispanic White only                    White only
# 2  Non-Hispanic Black/African American only   Black/African American only
# 3                  Non-Hispanic White only                    White only
# 4                  Non-Hispanic White only                    White only
#
#   DISAB3_A YRSINUS_A                             CITZNSTP_A  ...  \
# 0    Yes         NaN  Yes, a citizen of the United States    ...
# ...
